# %%
# import libraries

# 1. to handle the data
import pandas as pd
import numpy as np

# 2. To Viusalize the data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# from yellowbrick.cluster import KElbowVisualizer
from matplotlib.colors import ListedColormap

# 3. To preprocess the data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer

# 4. import Iterative imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# 5. Machine Learning
from sklearn.model_selection import train_test_split,GridSearchCV, cross_val_score

# 6. For Classification task.
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier,RandomForestRegressor
# from xgboost import XGBClassifier

# 7. Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 8. Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_csv(r"D:\MLDP Project\MLDP-Project---Heart-Disease-Prediction\data\heart_disease_uci.csv")

# %%
# Exploring the data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
# Checking the data shape
df.shape

#920 ID's
#16 Columns
# Out:
# (920, 16)

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Missing values summary (from your dataset)
missing_counts = {
    "trestbps": 59,
    "chol": 30,
    "fbs": 90,
    "restecg": 2,
    "thalch": 55,
    "exang": 55,
    "oldpeak": 62,
    "slope": 309,
    "ca": 611,
    "thal": 486
}

# Convert to DataFrame for convenience
missing_df = pd.DataFrame(list(missing_counts.items()), columns=["Column", "MissingValues"])

# Plot pie chart
plt.figure(figsize=(8,8))
plt.pie(
    missing_df["MissingValues"],
    labels=missing_df["Column"],
    autopct="%1.1f%%",
    startangle=140
)
plt.title("Distribution of Missing Values per Column")
plt.show()

# %%
##Renaming the Column Names

df = df.rename(columns={
    "id": "patient_id",
    "age": "age_years",
    "origin": "study_origin",
    "sex": "sex_male_female",
    "cp": "chest_pain_type",
    "trestbps": "resting_bp_mmHg",
    "chol": "serum_cholesterol_mgdl",
    "fbs": "fasting_blood_sugar_gt120",
    "restecg": "resting_ecg_result",
    "thalach": "max_heart_rate",
    "exang": "exercise_induced_angina",
    "oldpeak": "st_depression_exercise",
    "slope": "st_slope_peak_exercise",
    "ca": "num_major_vessels",
    "thal": "thal_defect_type",
    "num": "heart_disease_presence"
})

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Missing values summary (with descriptive names)
missing_counts = {
    "resting_bp_mmHg": 59,                # trestbps
    "serum_cholesterol_mgdl": 30,         # chol
    "fasting_blood_sugar_gt120": 90,      # fbs
    "resting_ecg_result": 2,              # restecg
    "max_heart_rate": 55,                 # thalach
    "exercise_induced_angina": 55,        # exang
    "st_depression_exercise": 62,         # oldpeak
    "st_slope_peak_exercise": 309,        # slope
    "num_major_vessels": 611,             # ca
    "thal_defect_type": 486               # thal
}

# Convert to DataFrame for convenience
missing_df = pd.DataFrame(list(missing_counts.items()), columns=["Column", "MissingValues"])

# Plot pie chart
plt.figure(figsize=(9,9))
plt.pie(
    missing_df["MissingValues"],
    labels=missing_df["Column"],
    autopct="%1.1f%%",
    startangle=140
)
plt.title("Distribution of Missing Values per Column (Descriptive Names)")
plt.show()

# %%
## Removing Missing Values

import pandas as pd

# Example: assume df is your DataFrame
df["severity_label"] = df["heart_disease_presence"].apply(lambda x: "Normal" if x == 0 else "Very Severe")

# Check the mapping
print(df[["heart_disease_presence", "severity_label"]].head(10))
# Out:
#    heart_disease_presence severity_label
# 0                       0         Normal
# 1                       2    Very Severe
# 2                       1    Very Severe
# 3                       0         Normal
# 4                       0         Normal
# 5                       0         Normal
# 6                       3    Very Severe
# 7                       0         Normal
# 8                       2    Very Severe
# 9                       1    Very Severe

# %%
df
# Out:
#      patient_id  age_years sex_male_female        dataset  chest_pain_type  \
# 0             1         63            Male      Cleveland   typical angina
# 1             2         67            Male      Cleveland     asymptomatic
# 2             3         67            Male      Cleveland     asymptomatic
# 3             4         37            Male      Cleveland      non-anginal
# 4             5         41          Female      Cleveland  atypical angina
# ..          ...        ...             ...            ...              ...
# 915         916         54          Female  VA Long Beach     asymptomatic
# 916         917         62            Male  VA Long Beach   typical angina
# 917         918         55            Male  VA Long Beach     asymptomatic
# 918         919         58            Male  VA Long Beach     asymptomatic
# 919         920         62            Male  VA Long Beach  atypical angina
#
#      resting_bp_mmHg  serum_cholesterol_mgdl fasting_blood_sugar_gt120  \
# 0              145.0                   233.0                      True
# 1              160.0                   286.0                     False
# 2              120.0                   229.0                     False
# 3              130.0                   250.0                     False
# 4              130.0                   204.0                     False
# ..               ...                     ...                       ...
# 915            127.0                   333.0                      True
# 916              NaN                   139.0                     False
# 917            122.0                   223.0                      True
# 918              NaN                   385.0                      True
# 919            120.0                   254.0                     False
#
#     resting_ecg_result  thalch exercise_induced_angina  \
# 0       lv hypertrophy   150.0                   False
# 1       lv hypertrophy   108.0                    True
# 2       lv hypertrophy   129.0                    True
# 3               normal   187.0                   False
# 4       lv hypertrophy   172.0                   False
# ..                 ...     ...                     ...
# 915   st-t abnormality   154.0                   False
# 916   st-t abnormality     NaN                     NaN
# 917   st-t abnormality   100.0                   False
# 918     lv hypertrophy     NaN                     NaN
# 919     lv hypertrophy    93.0                    True
#
#      st_depression_exercise st_slope_peak_exercise  num_major_vessels  \
# 0                       2.3            downsloping                0.0
# 1                       1.5                   flat                3.0
# 2                       2.6                   flat                2.0
# 3                       3.5            downsloping                0.0
# 4                       1.4              upsloping                0.0
# ..                      ...                    ...                ...
# 915                     0.0                    NaN                NaN
# 916                     NaN                    NaN                NaN
# 917                     0.0                    NaN                NaN
# 918                     NaN                    NaN                NaN
# 919                     0.0                    NaN                NaN
#
#       thal_defect_type  heart_disease_presence severity_label
# 0         fixed defect                       0         Normal
# 1               normal                       2    Very Severe
# 2    reversable defect                       1    Very Severe
# 3               normal                       0         Normal
# 4               normal                       0         Normal
# ..                 ...                     ...            ...
# 915                NaN                       1    Very Severe
# 916                NaN                       0         Normal
# 917       fixed defect                       2    Very Severe
# 918                NaN                       0         Normal
# 919                NaN                       1    Very Severe
#
# [920 rows x 17 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# If you already created severity_label (Normal vs Very Severe)
hue_col = "severity_label" if "severity_label" in df.columns else "num"

# Create pair plot
sns.pairplot(df, hue=hue_col, diag_kind="kde", plot_kws={"alpha":0.6})
plt.suptitle("Pair Plot of Heart Disease Dataset", y=1.02)
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['patient_id', 'age_years', 'sex_male_female', 'dataset', 'chest_pain_type', 'resting_bp_mmHg', 'serum_cholesterol_mgdl', 'fasting_blood_sugar_gt120', 'resting_ecg_result', 'thalch', 'exercise_induced_angina', 'st_depression_exercise', 'st_slope_peak_exercise', 'num_major_vessels', 'thal_defect_type', 'heart_disease_presence', 'severity_label']

# %%
df = df.drop(columns=["patient_id", "dataset", "severity_label"])
## predicting severity of Heart Disease

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chosen the target column for coloring
hue_col = "severity_label" if "severity_label" in df.columns else "heart_disease_presence"

# Selected only the numeric predictors + target column
plot_cols = ["age_years", "resting_bp_mmHg", "serum_cholesterol_mgdl",
             "thalch", "st_depression_exercise", "num_major_vessels"]

plot_df = df[plot_cols + [hue_col]]

# Create pair plot
sns.pairplot(plot_df,
             hue=hue_col,
             diag_kind="kde",
             plot_kws={"alpha":0.6})

plt.suptitle("Pair Plot of Selected Heart Disease Features", y=1.02)  
plt.show()

# %%
df.info
# Out:
# <bound method DataFrame.info of      age_years sex_male_female  chest_pain_type  resting_bp_mmHg  \
# 0           63            Male   typical angina            145.0
# 1           67            Male     asymptomatic            160.0
# 2           67            Male     asymptomatic            120.0
# 3           37            Male      non-anginal            130.0
# 4           41          Female  atypical angina            130.0
# ..         ...             ...              ...              ...
# 915         54          Female     asymptomatic            127.0
# 916         62            Male   typical angina              NaN
# 917         55            Male     asymptomatic            122.0
# 918         58            Male     asymptomatic              NaN
# 919         62            Male  atypical angina            120.0
#
#      serum_cholesterol_mgdl fasting_blood_sugar_gt120 resting_ecg_result  \
# 0                     233.0                      True     lv hypertrophy
# 1                     286.0                     False     lv hypertrophy
# 2                     229.0                     False     lv hypertrophy
# 3                     250.0                     False             normal
# 4                     204.0                     False     lv hypertrophy
# ..                      ...                       ...                ...
# 915                   333.0                      True   st-t abnormality
# 916                   139.0                     False   st-t abnormality
# 917                   223.0                      True   st-t abnormality
# 918                   385.0                      True     lv hypertrophy
# 919                   254.0                     False     lv hypertrophy
#
#      thalch exercise_induced_angina  st_depression_exercise  \
# 0     150.0                   False                     2.3
# 1     108.0                    True                     1.5
# 2     129.0                    True                     2.6
# 3     187.0                   False                     3.5
# 4     172.0                   False                     1.4
# ..      ...                     ...                     ...
# 915   154.0                   False                     0.0
# 916     NaN                     NaN                     NaN
# 917   100.0                   False                     0.0
# 918     NaN                     NaN                     NaN
# 919    93.0                    True                     0.0
#
#     st_slope_peak_exercise  num_major_vessels   thal_defect_type  \
# 0              downsloping                0.0       fixed defect
# 1                     flat                3.0             normal
# 2                     flat                2.0  reversable defect
# 3              downsloping                0.0             normal
# 4                upsloping                0.0             normal
# ..                     ...                ...                ...
# 915                    NaN                NaN                NaN
# 916                    NaN                NaN                NaN
# 917                    NaN                NaN       fixed defect
# 918                    NaN                NaN                NaN
# 919                    NaN                NaN                NaN
#
#      heart_disease_presence
# 0                         0
# 1                         2
# 2                         1
# 3                         0
# 4                         0
# ..                      ...
# 915                       1
# 916                       0
# 917                       2
# 918                       0
# 919                       1
#
# [920 rows x 14 columns]>

# %%
# Drop rows with any missing values
df = df.dropna()

# Drop columns with too many missing values
df = df.dropna(axis=1)

# %%
# Check how many missing values per column
print(df.isnull().sum())

# Check if any missing values exist
print(df.isnull().any())

#Cleaned and Removed Missing Values
# Out:
# age_years                    0
# sex_male_female              0
# chest_pain_type              0
# resting_bp_mmHg              0
# serum_cholesterol_mgdl       0
# fasting_blood_sugar_gt120    0
# resting_ecg_result           0
# thalch                       0
# exercise_induced_angina      0
# st_depression_exercise       0
# st_slope_peak_exercise       0
# num_major_vessels            0
# thal_defect_type             0
# heart_disease_presence       0
# dtype: int64
# age_years                    False
# sex_male_female              False
# chest_pain_type              False
# resting_bp_mmHg              False
# serum_cholesterol_mgdl       False
# fasting_blood_sugar_gt120    False
# resting_ecg_result           False
# thalch                       False
# exercise_induced_angina      False
# st_depression_exercise       False
# st_slope_peak_exercise       False
# num_major_vessels            False
# thal_defect_type             False
# heart_disease_presence       False
# dtype: bool

# %%
# Checking the data shape
df.shape

#299 Rows and 13 columns
# Out:
# (299, 14)

# %%
df.to_excel(r"D:\MLDP Project\data\heart_disease_clean.xlsx", index=False)

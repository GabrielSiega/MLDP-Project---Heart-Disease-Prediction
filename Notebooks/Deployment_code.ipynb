# %%
#Import the libraries

import numpy as np
from flask import Flask, request, jsonify, render_template
import joblib
import pandas as pd

# %%
#Creating the Flask app and Loading the trained model
app = Flask(__name__)
model = joblib.load('Models/trained_HD_model.pkl')

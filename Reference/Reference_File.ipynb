# %%
#######################################
####
🎛 HYPERPARAMETERS TUNING
🎛 ####
#######################################

## A. Grid Search ##
from sklearn.model_selection import GridSearchCV

param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10]
}

gs_rf = GridSearchCV(estimator=rf,
                     param_grid=param_grid_rf,
                     cv=5)
gs_rf.fit(X_train, y_train)

# Get best settings
best_params = gs_rf.best_params_
best_model = gs_rf.best_estimator_

#################################
## B. Randomized Search ##
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Define the range of settings
param_dist_rf = {
    'n_estimators': randint(50, 200),
    'max_depth': randint(2, 10)
}

rs_rf = RandomizedSearchCV(estimator=rf,
                           param_distributions=param_dist_rf,
                           cv=5,
                           n_iter=10,
                           random_state=42)
rs_rf.fit(X_train, y_train)

#################################
####
📈 MODEL EVALUATION
📈 ####
#################################

# Making Predictions:
y_pred = model.predict(X_test)

## A. Evaluating Regression ##
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Calculate Error
error = y_pred - y_test

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

## B. Evaluating Classification ##
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Accuracy
acc = accuracy_score(y_test, y_pred)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Detailed Report (Precision, Recall, F1-Score)
report = classification_report(y_test, y_pred)

###########################
####
🚀 Deployment
🚀 ####
###########################

import joblib

# Save the model
joblib.dump(model, "model_filename.pkl")

# Load the model later
loaded_model = joblib.load("model_filename.pkl")

######################################
####
🔍 UNSUPERVISED LEARNING
🔍 ####
######################################

## A. K-Means Clustering ##
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
kmeans.fit(X)

## Evaluating Clustering (Elbow Method): To find best number of clusters (K).
WCSS = []
for clusters in range(1, 10):
    kmeans = KMeans(n_clusters=clusters,
                    init='k-means++',
                    max_iter=300,
                    n_init=10,
                    random_state=42)
    kmeans.fit(X)
    WCSS.append(kmeans.inertia_)

# Plot WCSS vs clusters to find the "elbow" point

## B. Principal Component Analysis (PCA) ##
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca.fit(X)
X_pca = pca.transform(X)
